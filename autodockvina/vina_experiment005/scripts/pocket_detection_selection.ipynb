# %%
###This is the script for pocket detection via fpocket and selection via different parameters and the results from P2Rank
#since P2Rank runs in bash, this line of code has to be run first:
#/home/sylviane/meet-eu/Heidelberg_Team_2-1/P2Rank/p2rank_2.5.1/prank predict -f /home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_data/struc
#tures/8I92_ACE2.pdb

#these libraries need to be activated:
import nglview as nv
import re
import ipywidgets
import shutil
import zipfile
import pandas as pd
import numpy as np
from biobb_structure_utils.utils.extract_molecule import extract_molecule
from biobb_vs.fpocket.fpocket_run import fpocket_run
from biobb_vs.fpocket.fpocket_filter import fpocket_filter
from pathlib import Path, PurePath
from Bio.PDB import PDBParser
import glob

########################## user set-up ##########################
#input pdb file path and file name:
pdb_file = "/home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_data/structures/8WM3_Tiagabine_ACE2.pdb"

#is there a ligand in the pdb_file that needs to be removed?
ligand_pdb = 'yes'

#computed P2Rank prediction
P2_dir = '/home/sylviane/meet-eu/Heidelberg_Team_2-1/P2Rank/p2rank_2.5.1/test_output/predict_8WM3_Tiagabine_ACE2/8WM3_Tiagabine_ACE2.pdb_predictions.csv'

#This is the file path under which all files will be stored
#make sure that all base folders exist:
base_dir = Path("/home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_data/8WM3_ACE2_test")
base_dir.mkdir(parents=True, exist_ok=True)

#properties for fpocket-computation
properties_fpocket = {"min_radius":3, "max_radius": 6, "num_spheres": 35}

#parameters for fpocket selection
fpocket_params = {"volume": [500, 1200], 
                 "druggability_score": [0.5, 1],
                 "number_of_alpha_spheres": [35,],
                 "score": [0, 1]}

#thresholds for P2Rank selection
P2_score = 5 #score: #60-100: high confidence, 40-60: moderate confidence, <40: bad
P2_probability = 0.5
P2_rank = 10

#max distance between pockets to be selected
threshold = 6.0


########################## start of pipe ##########################
#These files will be creared automatically later:
filtered_fpockets_dir = base_dir / 'pockets_dir'
filtered_fpockets_dir.mkdir(parents=True, exist_ok=True)
#output path all fpockets as zip
output_fpockets_zip = base_dir / 'temp' / 'all_fpockets.zip'
#output path all fpockets summary
output_fpockets_summary = base_dir / 'temp' / 'fpocket_summary.json'
#output path filtered pockets
output_filtered_fpockets_zip = base_dir / 'temp' / 'fpocket_filtered.zip'
output_fpockets_zip.parent.mkdir(parents=True, exist_ok=True)
#output file with fpocket centers
output_fpocket_centers = base_dir / 'temp' / 'fpocket_centers.csv'
#output filtered P2Rank pockets
output_P2pocket_filtered = base_dir / 'temp' / 'P2rank_filtered.csv'
#output matching pockets
output_pocket_matches = base_dir / 'pockets_final.csv'

########################## fpocket prediction ##########################
## .pdb file pre-processing
#if the the protein in the .pdb file is bound to a ligand, this is removed herre

if ligand_pdb == 'yes':
    extract_molecule(input_structure_path = pdb_file,
                     output_molecule_path = pdb_file) #hier testen ob überschreiben funktioniert

##run fpocket to detect all pockets according to the set properties
fpocket_run(input_pdb_path = pdb_file, 
            output_pockets_zip = str(output_fpockets_zip),
            output_summary = str(output_fpockets_summary),
            properties = properties_fpocket)


##filter the computed pockets according to the set parameters
fpocket_filter(input_pockets_zip = str(output_fpockets_zip),
               input_summary = str(output_fpockets_summary),
               output_filter_pockets_zip = str(output_filtered_fpockets_zip),
               properties = fpocket_params)


##extract the filtered pockets and store them in a directory
with zipfile.ZipFile(str(output_filtered_fpockets_zip), 'r') as zip_ref:
    zip_ref.extractall(str(filtered_fpockets_dir))

##now we prepare the fpocket files for the comparison later
#the fpocket files first need to be converted into a common csv file:
fpocket_files = glob.glob(str(filtered_fpockets_dir / "pocket*_atm.pdb"))

fpocket_list = []

for fpocket_file in fpocket_files:
    parser = PDBParser(QUIET=True)
    structure = parser.get_structure('pocket', fpocket_file)
    coords = np.array([atom.get_coord() for atom in structure.get_atoms()])
    center = coords.mean(axis=0)  # center of mass of pocket atoms
    volume = len(coords)  # rough proxy for size
    pocket_id = fpocket_file.split('/')[-1].replace('.pdb','')
    fpocket_list.append({
        'pocket_id': pocket_id,
        'center_x': center[0],
        'center_y': center[1],
        'center_z': center[2],
        'volume': volume
    })

fpocket_df = pd.DataFrame(fpocket_list)
fpocket_df.to_csv(str(output_fpocket_centers), index=False)


########################## P2Rank filtering ##########################
#these are the P2Rank output files we are going to need ('.pdb_predictions.csv'):
P2pockets = pd.read_csv(str(P2_dir))

#strip empty spaces
P2pockets.columns = P2pockets.columns.str.strip()

P2pockets_filtered = P2pockets[
    (P2pockets['score'] >= P2_score) &
    (P2pockets['probability'] >= P2_probability) &
    (P2pockets['rank'] <= P2_rank)
]

P2pockets_filtered.to_csv(str(output_P2pocket_filtered))


########################## fpocket and P2Rank comparison ##########################
#we are comparing pockets via the distance of their centers. The centers need to be closer than the set threshold (in armstrong) to be considered one
#Here's a function that computes the distance between two points (d=√((x_2-x_1)²+(y_2-y_1)²+(z_2-z_1)²)) with p = (x, y, z):
def dist(p1, p2):
    return np.sqrt((p1[0]-p2[0])**2 + (p1[1]-p2[1])**2 + (p1[2]-p2[2])**2)

#now, let's look for matches:
#fpocket_df and P2pockets_filtered are the variables needed

matches = []
for i, p2 in P2pockets_filtered.iterrows():
    p2_center = [p2['center_x'], p2['center_y'], p2['center_z']]
    for j, fp in fpocket_df.iterrows():
        fp_center = [fp['center_x'], fp['center_y'], p2['center_z']]
        if dist(p2_center, fp_center) <= threshold:
            matches.append({
                'p2rank_rank': p2['rank'],
                'fpocket_nr': fp['pocket_id'],
                'distance': dist(p2_center, fp_center),
                'fpocket_center' : fp_center,
                'p2Rank_center' : p2_center
            })
matches_df = pd.DataFrame(matches)
matches_df.to_csv(str(output_pocket_matches))
# Out:
# 2025-12-13 07:01:49,625 [MainThread  ] [INFO ]  Module: biobb_structure_utils.utils.extract_molecule Version: 5.1.0
# 2025-12-13 07:01:49,627 [MainThread  ] [INFO ]  /home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_scripts/sandbox_e42edfeb-e3b6-41f0-aac7-6266dba1f438 directory successfully created
# 2025-12-13 07:01:49,629 [MainThread  ] [INFO ]  Copy: /home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_data/structures/8WM3_Tiagabine_ACE2.pdb to /home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_scripts/sandbox_e42edfeb-e3b6-41f0-aac7-6266dba1f438
# 2025-12-13 07:01:49,630 [MainThread  ] [INFO ]  Creating 9bd0aced-2bf6-4059-9146-6c9dae3bf0b7 temporary folder
# 2025-12-13 07:01:49,631 [MainThread  ] [INFO ]  check_structure -i /home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_data/structures/8WM3_Tiagabine_ACE2.pdb -o /home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_data/structures/8WM3_Tiagabine_ACE2.pdb --force_save --non_interactive command_list --list 9bd0aced-2bf6-4059-9146-6c9dae3bf0b7/extract_prot.lst
#
# 2025-12-13 07:01:50,160 [MainThread  ] [INFO ]  Executing: check_structure -i /home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_data/struc...
# 2025-12-13 07:01:50,161 [MainThread  ] [INFO ]  Exit code: 0
# 2025-12-13 07:01:50,161 [MainThread  ] [INFO ]  ================================================================================
# =                   BioBB structure checking utility v3.15.6                   =
# =            P. Andrio, A. Hospital, G. Bayarri, J.L. Gelpi 2018-23            =
# ================================================================================
#
# Warning: sequence features may not be available, use --sequence for  external fasta input
# Structure /home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_data/structures/8WM3_Tiagabine_ACE2.pdb loaded
#  PDB id:
#  Title:
#  Experimental method: unknown
#  Resolution (A): N.A.
#
#  Num. models: 1
#  Num. chains: 2 (C: Protein, D: Protein)
#  Num. residues:  1322
#  Num. residues with ins. codes:  0
#  Num. residues with H atoms: 0
#  Num. HETATM residues:  1
#  Num. ligands or modified residues:  1
#  Num. water mol.:  0
#  Num. atoms:  10612
# Small mol ligands found
# TGI C602
#
# Step 1: ligands --remove All
#
# Running ligands. Options: --remove All
# Detected 1 Ligands
#  TGI C602
# Ligands removed All (1)
#
# Step 2: water --remove Yes
#
# Running water. Options: --remove Yes
# No water molecules found
# Command list completed
# Final Num. models: 1
# Final Num. chains: 2 (C: Protein, D: Protein)
# Final Num. residues:  1321
# Final Num. residues with ins. codes:  0
# Final Num. residues with H atoms: 0
# Final Num. HETATM residues:  0
# Final Num. ligands or modified residues:  0
# Final Num. water mol.:  0
# Final Num. atoms:  10587
# Structure saved on /home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_data/structures/8WM3_Tiagabine_ACE2.pdb
#
# 2025-12-13 07:01:50,165 [MainThread  ] [INFO ]  Removed: ['/home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_scripts/sandbox_e42edfeb-e3b6-41f0-aac7-6266dba1f438']
# 2025-12-13 07:01:50,166 [MainThread  ] [INFO ]
# 2025-12-13 07:01:50,169 [MainThread  ] [INFO ]  Module: biobb_vs.fpocket.fpocket_run Version: 5.1.0
# 2025-12-13 07:01:50,170 [MainThread  ] [INFO ]  /home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_scripts/sandbox_aac1cbcb-a3b8-44f2-a91d-6ddb5453ddf9 directory successfully created
# 2025-12-13 07:01:50,172 [MainThread  ] [INFO ]  Copy: /home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_data/structures/8WM3_Tiagabine_ACE2.pdb to /home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_scripts/sandbox_aac1cbcb-a3b8-44f2-a91d-6ddb5453ddf9
# 2025-12-13 07:01:50,173 [MainThread  ] [INFO ]  Creating 321e7acc-b5ce-4866-acec-81a53831a944 temporary folder
# 2025-12-13 07:01:50,176 [MainThread  ] [INFO ]  Executing fpocket
# 2025-12-13 07:01:50,176 [MainThread  ] [INFO ]  fpocket -f 321e7acc-b5ce-4866-acec-81a53831a944/input.pdb -m 3 -M 6 -i 35
#
# 2025-12-13 07:02:01,285 [MainThread  ] [INFO ]  Executing: fpocket -f 321e7acc-b5ce-4866-acec-81a53831a944/input.pdb -m 3 -M 6 -i 35...
# 2025-12-13 07:02:01,287 [MainThread  ] [INFO ]  Exit code: 0
# 2025-12-13 07:02:01,287 [MainThread  ] [INFO ]  ***** POCKET HUNTING BEGINS *****
# ***** POCKET HUNTING ENDS *****
#
# 2025-12-13 07:02:01,296 [MainThread  ] [INFO ]  61 pockets found
# 2025-12-13 07:02:01,296 [MainThread  ] [INFO ]  Sorting output data by druggability_score
# 2025-12-13 07:02:01,313 [MainThread  ] [INFO ]  Adding:
# 2025-12-13 07:02:01,314 [MainThread  ] [INFO ]  ['321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket10_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket10_vert.pqr', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket11_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket11_vert.pqr', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket12_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket12_vert.pqr', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket13_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket13_vert.pqr', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket14_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket14_vert.pqr', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket15_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket15_vert.pqr', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket16_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket16_vert.pqr', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket17_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket17_vert.pqr', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket18_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket18_vert.pqr', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket19_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket19_vert.pqr', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket1_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket1_vert.pqr', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket20_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket20_vert.pqr', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket21_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket21_vert.pqr', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket22_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket22_vert.pqr', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket23_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket23_vert.pqr', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket24_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket24_vert.pqr', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket25_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket25_vert.pqr', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket26_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket26_vert.pqr', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket27_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket27_vert.pqr', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket28_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket28_vert.pqr', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket29_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket29_vert.pqr', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket2_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket2_vert.pqr', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket30_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket30_vert.pqr', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket31_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket31_vert.pqr', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket32_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket32_vert.pqr', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket33_atm.pdb', '321e7acc-b5ce-4866-acec-81a53831a944/input_out/pockets/pocket33_vert.pqr', '321e7acc-b5ce-4866-acec-81a5 ...
# 2025-12-13 07:02:01,316 [MainThread  ] [INFO ]  to: /home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_data/8WM3_ACE2_test/temp/all_fpockets.zip
# 2025-12-13 07:02:01,316 [MainThread  ] [INFO ]  Saving summary to /home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_data/8WM3_ACE2_test/temp/fpocket_summary.json file
# 2025-12-13 07:02:01,328 [MainThread  ] [INFO ]  Removed: ['/home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_scripts/sandbox_aac1cbcb-a3b8-44f2-a91d-6ddb5453ddf9', '321e7acc-b5ce-4866-acec-81a53831a944']
# 2025-12-13 07:02:01,333 [MainThread  ] [INFO ]  Module: biobb_vs.fpocket.fpocket_filter Version: 5.1.0
# 2025-12-13 07:02:01,334 [MainThread  ] [INFO ]  /home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_scripts/sandbox_95a41ae1-0e1b-4644-8ce4-d536dbb9312d directory successfully created
# 2025-12-13 07:02:01,337 [MainThread  ] [INFO ]  Copy: /home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_data/8WM3_ACE2_test/temp/all_fpockets.zip to /home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_scripts/sandbox_95a41ae1-0e1b-4644-8ce4-d536dbb9312d
# 2025-12-13 07:02:01,338 [MainThread  ] [INFO ]  Copy: /home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_data/8WM3_ACE2_test/temp/fpocket_summary.json to /home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_scripts/sandbox_95a41ae1-0e1b-4644-8ce4-d536dbb9312d
# 2025-12-13 07:02:01,339 [MainThread  ] [INFO ]  Performing a search under the next parameters: score: [0.0, 1.0], druggability_score: [0.5, 1.0], volume: [500.0, 1200.0]
# 2025-12-13 07:02:01,340 [MainThread  ] [INFO ]  Found 9 matches:
# **********
# pocket10
# **********
# score: 0.364
# druggability_score: 0.957
# volume: 807.816
#
# **********
# pocket6
# **********
# score: 0.492
# druggability_score: 0.911
# volume: 562.319
#
# **********
# pocket9
# **********
# score: 0.466
# druggability_score: 0.906
# volume: 747.157
#
# **********
# pocket3
# **********
# score: 0.636
# druggability_score: 0.902
# volume: 1092.785
#
# **********
# pocket14
# **********
# score: 0.212
# druggability_score: 0.813
# volume: 621.989
#
# **********
# pocket19
# **********
# score: 0.169
# druggability_score: 0.754
# volume: 612.441
#
# **********
# pocket1
# **********
# score: 0.773
# druggability_score: 0.685
# volume: 909.159
#
# **********
# pocket21
# **********
# score: 0.129
# druggability_score: 0.657
# volume: 1085.619
#
# **********
# pocket5
# **********
# score: 0.516
# druggability_score: 0.651
# volume: 517.073
#
# 2025-12-13 07:02:01,341 [MainThread  ] [INFO ]  Creating 6ae931d4-8726-4eaa-8711-7ce1436e9ce2 temporary folder
# 2025-12-13 07:02:01,360 [MainThread  ] [INFO ]  Extracting: /home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_data/8WM3_ACE2_test/temp/all_fpockets.zip
# 2025-12-13 07:02:01,361 [MainThread  ] [INFO ]  to:
# 2025-12-13 07:02:01,362 [MainThread  ] [INFO ]  ['6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket10_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket10_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket11_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket11_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket12_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket12_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket13_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket13_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket14_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket14_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket15_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket15_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket16_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket16_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket17_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket17_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket18_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket18_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket19_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket19_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket1_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket1_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket20_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket20_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket21_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket21_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket22_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket22_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket23_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket23_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket24_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket24_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket25_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket25_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket26_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket26_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket27_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket27_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket28_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket28_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket29_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket29_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket2_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket2_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket30_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket30_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket31_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket31_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket32_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket32_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket33_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket33_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket34_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket34_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket35_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket35_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket36_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket36_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket37_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket37_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket38_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket38_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket39_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket39_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket3_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket3_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket40_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket40_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket41_ ...
# 2025-12-13 07:02:01,363 [MainThread  ] [INFO ]  Creating /home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_data/8WM3_ACE2_test/temp/fpocket_filtered.zip output file
# 2025-12-13 07:02:01,366 [MainThread  ] [INFO ]  Adding:
# 2025-12-13 07:02:01,367 [MainThread  ] [INFO ]  ['6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket10_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket10_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket14_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket14_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket19_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket19_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket1_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket1_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket21_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket21_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket3_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket3_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket5_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket5_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket6_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket6_vert.pqr', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket9_atm.pdb', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2/pocket9_vert.pqr']
# 2025-12-13 07:02:01,368 [MainThread  ] [INFO ]  to: /home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_data/8WM3_ACE2_test/temp/fpocket_filtered.zip
# 2025-12-13 07:02:01,376 [MainThread  ] [INFO ]  Removed: ['/home/sylviane/meet-eu/Heidelberg_Team_2-1/fpocket_scripts/sandbox_95a41ae1-0e1b-4644-8ce4-d536dbb9312d', '6ae931d4-8726-4eaa-8711-7ce1436e9ce2']
# 2025-12-13 07:02:01,377 [MainThread  ] [INFO ]
# /home/sylviane/miniconda3/envs/fpocket_env/lib/python3.11/site-packages/biobb_common/generic/biobb_object.py:183: UserWarning: Warning: number_of_alpha_spheres is not a recognized property. The most similar property is: global_properties_list
#   warnings.warn(
